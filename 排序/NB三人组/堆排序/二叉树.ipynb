# %% [markdown]
# # 二叉树实现

# %% [markdown]
# ## 顺序存储方式
# ## 链式存储方式(此处暂且不写)

# %% [markdown]
# ## 以此二叉树为例

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 顺序存储为上图所示

# %% [markdown]
# ## 数学理解

# %%
# 对于左子树
# i -> 2i + 1  此处i代表父节点 它的子树的子节点 就是2i + 1 稍微推理即可得到

# 对于右子树
# i -> 2i + 2  此处i代表父节点 它的子树的子节点 就是2i + 2 稍微推理即可得到
